# %%
import psycopg2

conn = psycopg2.connect(

    database="recruitverse",

    user="postgres",

    password="root123",

    host="localhost",

    port="5432"
)

cursor = conn.cursor()

cursor.execute("""

INSERT INTO candidates (

    name,
    email,
    phone,
    education,
    experience_years

)

VALUES (

    'John Doe',
    'john@gmail.com',
    '9876543210',
    'B.Tech',
    3

);

""")

conn.commit()

print("Record Inserted")

conn.close()
# Out:
# Record Inserted
